# %%
import pandas as pd

pd.set_option('display.max_columns', None)

# %%
df = pd.read_csv("/home/john/code/arundelljr/MoneyBaller/raw_data/FC26_20250921.csv")
# Out:
# /tmp/ipykernel_37652/686258116.py:1: DtypeWarning: Columns (39) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("/home/john/code/arundelljr/MoneyBaller/raw_data/FC26_20250921.csv")

# %%
df.head(3)
# Out:
#    player_id                                player_url  fifa_version  \
# 0     252371    /player/252371/jude-bellingham/260004/            26
# 1     239053  /player/239053/federico-valverde/260004/            26
# 2     212622     /player/212622/joshua-kimmich/260004/            26
#
#    fifa_update fifa_update_date     short_name  \
# 0            4       2025-09-19  J. Bellingham
# 1            4       2025-09-19    F. Valverde
# 2            4       2025-09-19     J. Kimmich
#
#                             long_name player_positions  overall  potential  \
# 0      Jude Victor William Bellingham          CAM, CM       90         94
# 1  Federico Santiago Valverde Dipetta      CM, CDM, RB       89         90
# 2               Joshua Walter Kimmich      CDM, RB, CM       89         89
#
#    value_eur  wage_eur  age         dob  height_cm  weight_kg  league_id  \
# 0  174500000    320000   22  2003-06-29        186         75       53.0
# 1  120500000    340000   26  1998-07-22        182         74       53.0
# 2   86000000    140000   30  1995-02-08        177         75       19.0
#
#   league_name  league_level  club_team_id          club_name club_position  \
# 0     La Liga           1.0         243.0        Real Madrid           CAM
# 1     La Liga           1.0         243.0        Real Madrid           RDM
# 2  Bundesliga           1.0          21.0  FC Bayern München           RDM
#
#    club_jersey_number club_loaned_from club_joined_date  \
# 0                 5.0              NaN       2023-07-01
# 1                 8.0              NaN       2016-07-22
# 2                 6.0              NaN       2015-07-01
#
#    club_contract_valid_until_year  nationality_id nationality_name  \
# 0                          2029.0              14          England
# 1                          2029.0              60          Uruguay
# 2                          2029.0              21          Germany
#
#    nation_team_id nation_position  nation_jersey_number preferred_foot  \
# 0          1318.0             CAM                  10.0          Right
# 1             NaN             NaN                   NaN          Right
# 2          1337.0             RCM                   6.0          Right
#
#    weak_foot  skill_moves  international_reputation  work_rate  \
# 0          4            4                         5        NaN
# 1          4            3                         4        NaN
# 2          4            3                         4        NaN
#
#           body_type real_face  release_clause_eur  \
# 0  Normal (170-185)       Yes         370800000.0
# 1            Unique       Yes         256100000.0
# 2  Normal (170-185)       Yes         141900000.0
#
#                                          player_tags  \
# 0  #Dribbler, #Playmaker , #Clinical finisher, #C...
# 1  #Playmaker , #Distance shooter, #Tackling , #T...
# 2  #Playmaker , #Crosser, #Tackling , #Complete m...
#
#                                        player_traits  pace  shooting  passing  \
# 0  Relentless +, Low Driven Shot, Gamechanger, In...  80.0      86.0     83.0
# 1  Relentless +, Power Shot, Long Ball Pass, Inte...  88.0      84.0     84.0
# 2  Long Ball Pass +, Finesse Shot, Whipped Pass, ...  72.0      74.0     89.0
#
#    dribbling  defending  physic  attacking_crossing  attacking_finishing  \
# 0       90.0       78.0    85.0                  66                   88
# 1       84.0       83.0    85.0                  78                   80
# 2       84.0       83.0    79.0                  92                   68
#
#    attacking_heading_accuracy  attacking_short_passing  attacking_volleys  \
# 0                          75                       90                 77
# 1                          63                       88                 78
# 2                          72                       89                 69
#
#    skill_dribbling  skill_curve  skill_fk_accuracy  skill_long_passing  \
# 0               91           73                 68                  89
# 1               84           76                 69                  88
# 2               82           85                 79                  92
#
#    skill_ball_control  movement_acceleration  movement_sprint_speed  \
# 0                  91                     81                     80
# 1                  88                     84                     92
# 2                  86                     75                     70
#
#    movement_agility  movement_reactions  movement_balance  power_shot_power  \
# 0                83                  91                83                86
# 1                77                  89                68                91
# 2                83                  89                84                78
#
#    power_jumping  power_stamina  power_strength  power_long_shots  \
# 0             85             94              80                87
# 1             82             93              82                91
# 2             77             92              69                83
#
#    mentality_aggression  mentality_interceptions  mentality_positioning  \
# 0                    85                       82                     91
# 1                    81                       86                     86
# 2                    89                       85                     78
#
#    mentality_vision  mentality_penalties  mentality_composure  \
# 0                90                   74                   90
# 1                86                   59                   84
# 2                86                   71                   86
#
#    defending_marking_awareness  defending_standing_tackle  \
# 0                           77                         79
# 1                           82                         87
# 2                           82                         86
#
#    defending_sliding_tackle  goalkeeping_diving  goalkeeping_handling  \
# 0                        77                  14                    11
# 1                        86                   6                    10
# 2                        85                   8                    15
#
#    goalkeeping_kicking  goalkeeping_positioning  goalkeeping_reflexes  \
# 0                   10                        5                     8
# 1                    6                       15                     8
# 2                    7                       15                    15
#
#    goalkeeping_speed    ls    st    rs    lw    lf    cf    rf    rw   lam  \
# 0                NaN  86+3  86+3  86+3  87+0  89+0  89+0  89+0  87+0  89+3
# 1                NaN  84+3  84+3  84+3  85+0  86+0  86+0  86+0  85+0  86+3
# 2                NaN  77+3  77+3  77+3  82+0  81+0  81+0  81+0  82+0  83+3
#
#     cam   ram    lm   lcm    cm   rcm    rm   lwb   ldm   cdm   rdm   rwb  \
# 0  89+3  89+3  87+3  89+3  89+3  89+3  87+3  83+3  85+3  85+3  85+3  83+3
# 1  86+3  86+3  86+3  88+2  88+2  88+2  86+3  86+3  87+3  87+3  87+3  86+3
# 2  83+3  83+3  84+3  87+2  87+2  87+2  84+3  86+3  87+2  87+2  87+2  86+3
#
#      lb   lcb    cb   rcb    rb    gk  \
# 0  82+3  81+3  81+3  81+3  82+3  18+3
# 1  86+3  83+3  83+3  83+3  86+3  18+3
# 2  85+3  82+3  82+3  82+3  85+3  21+3
#
#                                      player_face_url
# 0  https://cdn.sofifa.net/players/252/371/26_120.png
# 1  https://cdn.sofifa.net/players/239/053/26_120.png
# 2  https://cdn.sofifa.net/players/212/622/26_120.png

# %%
df.columns[-28:-1]
# Out:
# Index(['ls', 'st', 'rs', 'lw', 'lf', 'cf', 'rf', 'rw', 'lam', 'cam', 'ram',
#        'lm', 'lcm', 'cm', 'rcm', 'rm', 'lwb', 'ldm', 'cdm', 'rdm', 'rwb', 'lb',
#        'lcb', 'cb', 'rcb', 'rb', 'gk'],
#       dtype='object')

# %%
drop_cols = df.columns[-28:-1]
df = df.drop(columns=drop_cols)

# %%
df['work_rate'].value_counts()
# Out:
# Series([], Name: count, dtype: int64)

# %%
df
# Out:
#        player_id                                player_url  fifa_version  \
# 0         252371    /player/252371/jude-bellingham/260004/            26
# 1         239053  /player/239053/federico-valverde/260004/            26
# 2         212622     /player/212622/joshua-kimmich/260004/            26
# 3         235212      /player/235212/achraf-hakimi/260004/            26
# 4         224232     /player/224232/nicolo-barella/260004/            26
# ...          ...                                       ...           ...
# 18400     267946        /player/267946/jun-sub-lim/260004/            26
# 18401      76593         /player/76593/jianxian-yu/260004/            26
# 18402      77205         /player/77205/man-ho-park/260004/            26
# 18403     278149     /player/278149/dipesh-chauhan/260004/            26
# 18404      79985        /player/79985/haochen-peng/260004/            26
#
#        fifa_update fifa_update_date     short_name  \
# 0                4       2025-09-19  J. Bellingham
# 1                4       2025-09-19    F. Valverde
# 2                4       2025-09-19     J. Kimmich
# 3                4       2025-09-19      A. Hakimi
# 4                4       2025-09-19     N. Barella
# ...            ...              ...            ...
# 18400            4       2025-09-19    Lim Jun Sub
# 18401            4       2025-09-19    Yu Jianxian
# 18402            4       2025-09-19    Park Man Ho
# 18403            4       2025-09-19     D. Chauhan
# 18404            4       2025-09-19   Peng Haochen
#
#                                 long_name player_positions  overall  \
# 0          Jude Victor William Bellingham          CAM, CM       90
# 1      Federico Santiago Valverde Dipetta      CM, CDM, RB       89
# 2                   Joshua Walter Kimmich      CDM, RB, CM       89
# 3            Achraf Hakimi Mouhأشرف حكيمي           RB, RM       89
# 4                          Nicolò Barella               CM       87
# ...                                   ...              ...      ...
# 18400                     Joon-seob Im임준섭               GK       48
# 18401                         Jianxian Yu               GK       49
# 18402                         Man Ho Park               GK       48
# 18403                      Dipesh Chauhan               GK       51
# 18404                        Haochen Peng               GK       49
#
#        potential  value_eur  wage_eur  age         dob  height_cm  weight_kg  \
# 0             94  174500000    320000   22  2003-06-29        186         75
# 1             90  120500000    340000   26  1998-07-22        182         74
# 2             89   86000000    140000   30  1995-02-08        177         75
# 3             90  111000000    170000   26  1998-11-04        181         73
# 4             87   79500000     69000   28  1997-02-07        175         68
# ...          ...        ...       ...  ...         ...        ...        ...
# 18400         54      60000       500   21  2003-08-22        194         90
# 18401         56      80000       500   23  2001-11-06        188         77
# 18402         59      90000       500   21  2004-02-28        184         77
# 18403         61     110000       500   21  2003-11-20        182         67
# 18404         58      90000       650   20  2005-03-09        176         68
#
#        league_id   league_name  league_level  club_team_id  \
# 0           53.0       La Liga           1.0         243.0
# 1           53.0       La Liga           1.0         243.0
# 2           19.0    Bundesliga           1.0          21.0
# 3           16.0       Ligue 1           1.0          73.0
# 4           31.0       Serie A           1.0          44.0
# ...          ...           ...           ...           ...
# 18400       83.0    K League 1           1.0         982.0
# 18401     2012.0  Super League           1.0      131531.0
# 18402       83.0    K League 1           1.0        2056.0
# 18403     2149.0  Super League           1.0      113040.0
# 18404     2012.0  Super League           1.0      116360.0
#
#                  club_name club_position  club_jersey_number club_loaned_from  \
# 0              Real Madrid           CAM                 5.0              NaN
# 1              Real Madrid           RDM                 8.0              NaN
# 2        FC Bayern München           RDM                 6.0              NaN
# 3      Paris Saint-Germain            RB                 2.0              NaN
# 4                    Inter           RCM                23.0              NaN
# ...                    ...           ...                 ...              ...
# 18400             FC Seoul           RES                25.0              NaN
# 18401         Yunnan Yukun           SUB                24.0              NaN
# 18402             Daegu FC           RES                51.0              NaN
# 18403     NorthEast United           RES                20.0              NaN
# 18404    Chengdu Rongcheng           RES                55.0              NaN
#
#       club_joined_date  club_contract_valid_until_year  nationality_id  \
# 0           2023-07-01                          2029.0              14
# 1           2016-07-22                          2029.0              60
# 2           2015-07-01                          2029.0              21
# 3           2021-07-06                          2029.0             129
# 4           2020-09-01                          2029.0              27
# ...                ...                             ...             ...
# 18400       2024-12-31                          2030.0             167
# 18401       2023-04-07                          2027.0             155
# 18402       2025-01-03                          2028.0             167
# 18403       2023-08-18                          2026.0             159
# 18404       2025-07-16                          2028.0             155
#
#       nationality_name  nation_team_id nation_position  nation_jersey_number  \
# 0              England          1318.0             CAM                  10.0
# 1              Uruguay             NaN             NaN                   NaN
# 2              Germany          1337.0             RCM                   6.0
# 3              Morocco        111111.0              RB                   2.0
# 4                Italy          1343.0             RCM                  18.0
# ...                ...             ...             ...                   ...
# 18400   Korea Republic             NaN             NaN                   NaN
# 18401         China PR             NaN             NaN                   NaN
# 18402   Korea Republic             NaN             NaN                   NaN
# 18403            India             NaN             NaN                   NaN
# 18404         China PR             NaN             NaN                   NaN
#
#       preferred_foot  weak_foot  skill_moves  international_reputation  \
# 0              Right          4            4                         5
# 1              Right          4            3                         4
# 2              Right          4            3                         4
# 3              Right          4            4                         4
# 4              Right          4            3                         4
# ...              ...        ...          ...                       ...
# 18400          Right          2            1                         1
# 18401          Right          2            1                         1
# 18402          Right          2            1                         1
# 18403          Right          1            1                         1
# 18404          Right          2            1                         1
#
#        work_rate         body_type real_face  release_clause_eur  \
# 0            NaN  Normal (170-185)       Yes         370800000.0
# 1            NaN            Unique       Yes         256100000.0
# 2            NaN  Normal (170-185)       Yes         141900000.0
# 3            NaN    Lean (170-185)       Yes         213700000.0
# 4            NaN     Normal (170-)       Yes         131199999.0
# ...          ...               ...       ...                 ...
# 18400        NaN       Lean (185+)        No             87000.0
# 18401        NaN     Normal (185+)        No            140000.0
# 18402        NaN  Normal (170-185)        No            131000.0
# 18403        NaN    Lean (170-185)        No            171000.0
# 18404        NaN  Normal (170-185)        No            158000.0
#
#                                              player_tags  \
# 0      #Dribbler, #Playmaker , #Clinical finisher, #C...
# 1      #Playmaker , #Distance shooter, #Tackling , #T...
# 2      #Playmaker , #Crosser, #Tackling , #Complete m...
# 3                                             #Speedster
# 4                                               #Acrobat
# ...                                                  ...
# 18400                                                NaN
# 18401                                                NaN
# 18402                                                NaN
# 18403                                                NaN
# 18404                                                NaN
#
#                                            player_traits  pace  shooting  \
# 0      Relentless +, Low Driven Shot, Gamechanger, In...  80.0      86.0
# 1      Relentless +, Power Shot, Long Ball Pass, Inte...  88.0      84.0
# 2      Long Ball Pass +, Finesse Shot, Whipped Pass, ...  72.0      74.0
# 3      Relentless +, Low Driven Shot, Whipped Pass, J...  92.0      79.0
# 4      Relentless +, Incisive Pass, Pinged Pass, Long...  80.0      78.0
# ...                                                  ...   ...       ...
# 18400                                                NaN   NaN       NaN
# 18401                                                NaN   NaN       NaN
# 18402                                                NaN   NaN       NaN
# 18403                                                NaN   NaN       NaN
# 18404                                                NaN   NaN       NaN
#
#        passing  dribbling  defending  physic  attacking_crossing  \
# 0         83.0       90.0       78.0    85.0                  66
# 1         84.0       84.0       83.0    85.0                  78
# 2         89.0       84.0       83.0    79.0                  92
# 3         82.0       83.0       82.0    79.0                  85
# 4         84.0       86.0       81.0    76.0                  79
# ...        ...        ...        ...     ...                 ...
# 18400      NaN        NaN        NaN     NaN                  12
# 18401      NaN        NaN        NaN     NaN                  10
# 18402      NaN        NaN        NaN     NaN                  13
# 18403      NaN        NaN        NaN     NaN                  11
# 18404      NaN        NaN        NaN     NaN                  13
#
#        attacking_finishing  attacking_heading_accuracy  \
# 0                       88                          75
# 1                       80                          63
# 2                       68                          72
# 3                       80                          71
# 4                       77                          60
# ...                    ...                         ...
# 18400                    8                          12
# 18401                    7                          11
# 18402                    8                          10
# 18403                    7                          13
# 18404                    8                          11
#
#        attacking_short_passing  attacking_volleys  skill_dribbling  \
# 0                           90                 77               91
# 1                           88                 78               84
# 2                           89                 69               82
# 3                           86                 74               82
# 4                           89                 80               84
# ...                        ...                ...              ...
# 18400                       23                  8               10
# 18401                       24                  7                5
# 18402                       23                  8                5
# 18403                       22                  7                5
# 18404                       17                  7                7
#
#        skill_curve  skill_fk_accuracy  skill_long_passing  skill_ball_control  \
# 0               73                 68                  89                  91
# 1               76                 69                  88                  88
# 2               85                 79                  92                  86
# 3               78                 80                  73                  85
# 4               79                 67                  87                  87
# ...            ...                ...                 ...                 ...
# 18400            9                 10                  22                  16
# 18401           12                 14                  17                  11
# 18402           12                 12                  20                  15
# 18403           13                 13                  17                  12
# 18404           13                 11                  29                  12
#
#        movement_acceleration  movement_sprint_speed  movement_agility  \
# 0                         81                     80                83
# 1                         84                     92                77
# 2                         75                     70                83
# 3                         89                     95                81
# 4                         82                     78                91
# ...                      ...                    ...               ...
# 18400                     26                     18                23
# 18401                     17                     23                30
# 18402                     20                     19                34
# 18403                     33                     29                22
# 18404                     16                     19                23
#
#        movement_reactions  movement_balance  power_shot_power  power_jumping  \
# 0                      91                83                86             85
# 1                      89                68                91             82
# 2                      89                84                78             77
# 3                      90                78                82             84
# 4                      91                88                80             75
# ...                   ...               ...               ...            ...
# 18400                  35                22                39             43
# 18401                  40                37                37             40
# 18402                  37                46                34             31
# 18403                  31                21                34             33
# 18404                  41                44                37             29
#
#        power_stamina  power_strength  power_long_shots  mentality_aggression  \
# 0                 94              80                87                    85
# 1                 93              82                91                    81
# 2                 92              69                83                    89
# 3                 95              72                77                    77
# 4                 89              66                79                    87
# ...              ...             ...               ...                   ...
# 18400             16              53                10                    18
# 18401             23              53                 8                    21
# 18402             27              42                 6                    18
# 18403             24              30                 6                    21
# 18404             16              37                 9                    27
#
#        mentality_interceptions  mentality_positioning  mentality_vision  \
# 0                           82                     91                90
# 1                           86                     86                86
# 2                           85                     78                86
# 3                           85                     84                78
# 4                           85                     84                85
# ...                        ...                    ...               ...
# 18400                       11                     10                30
# 18401                       10                      7                21
# 18402                        8                      6                30
# 18403                        9                      8                24
# 18404                        6                      7                21
#
#        mentality_penalties  mentality_composure  defending_marking_awareness  \
# 0                       74                   90                           77
# 1                       59                   84                           82
# 2                       71                   86                           82
# 3                       68                   84                           82
# 4                       73                   88                           80
# ...                    ...                  ...                          ...
# 18400                   10                   32                           12
# 18401                   15                   38                            9
# 18402                   13                   33                            9
# 18403                   15                   25                            8
# 18404                   10                   31                            7
#
#        defending_standing_tackle  defending_sliding_tackle  \
# 0                             79                        77
# 1                             87                        86
# 2                             86                        85
# 3                             85                        79
# 4                             85                        80
# ...                          ...                       ...
# 18400                         10                        13
# 18401                         11                        10
# 18402                         14                        11
# 18403                         14                        12
# 18404                         12                        13
#
#        goalkeeping_diving  goalkeeping_handling  goalkeeping_kicking  \
# 0                      14                    11                   10
# 1                       6                    10                    6
# 2                       8                    15                    7
# 3                      10                     8                   14
# 4                      11                     5                   13
# ...                   ...                   ...                  ...
# 18400                  45                    51                   52
# 18401                  46                    54                   49
# 18402                  48                    52                   45
# 18403                  60                    51                   45
# 18404                  49                    50                   49
#
#        goalkeeping_positioning  goalkeeping_reflexes  goalkeeping_speed  \
# 0                            5                     8                NaN
# 1                           15                     8                NaN
# 2                           15                    15                NaN
# 3                            6                     8                NaN
# 4                           14                    11                NaN
# ...                        ...                   ...                ...
# 18400                       46                    52               23.0
# 18401                       43                    51               19.0
# 18402                       42                    54               20.0
# 18403                       46                    52               31.0
# 18404                       49                    48               17.0
#
#                                          player_face_url
# 0      https://cdn.sofifa.net/players/252/371/26_120.png
# 1      https://cdn.sofifa.net/players/239/053/26_120.png
# 2      https://cdn.sofifa.net/players/212/622/26_120.png
# 3      https://cdn.sofifa.net/players/235/212/26_120.png
# 4      https://cdn.sofifa.net/players/224/232/26_120.png
# ...                                                  ...
# 18400  https://cdn.sofifa.net/players/267/946/26_120.png
# 18401  https://cdn.sofifa.net/players/076/593/26_120.png
# 18402  https://cdn.sofifa.net/players/077/205/26_120.png
# 18403  https://cdn.sofifa.net/players/278/149/26_120.png
# 18404  https://cdn.sofifa.net/players/079/985/26_120.png
#
# [18405 rows x 83 columns]

# %%
features_columns = ['player_id', 'short_name', 'long_name', 'player_positions',
       'overall', 'potential', 'height_cm', 'weight_kg', 'preferred_foot', 'weak_foot', 'skill_moves',
       'international_reputation', 'pace',
       'shooting', 'passing', 'dribbling', 'defending', 'physic',
       'attacking_crossing', 'attacking_finishing',
       'attacking_heading_accuracy', 'attacking_short_passing',
       'attacking_volleys', 'skill_dribbling', 'skill_curve',
       'skill_fk_accuracy', 'skill_long_passing', 'skill_ball_control',
       'movement_acceleration', 'movement_sprint_speed', 'movement_agility',
       'movement_reactions', 'movement_balance', 'power_shot_power',
       'power_jumping', 'power_stamina', 'power_strength', 'power_long_shots',
       'mentality_aggression', 'mentality_interceptions',
       'mentality_positioning', 'mentality_vision', 'mentality_penalties',
       'mentality_composure', 'defending_marking_awareness',
       'defending_standing_tackle', 'defending_sliding_tackle',
       'goalkeeping_diving', 'goalkeeping_handling', 'goalkeeping_kicking',
       'goalkeeping_positioning', 'goalkeeping_reflexes', 'goalkeeping_speed']

# %%
info_columns = ['player_id', 'player_url', 'short_name', 'long_name', 'player_positions',
       'overall', 'potential', 'value_eur', 'wage_eur', 'age', 'dob',
       'height_cm', 'weight_kg', 'league_id', 'league_name', 'league_level',
       'club_team_id', 'club_name', 'club_position', 'club_jersey_number',
       'club_loaned_from', 'club_joined_date',
       'club_contract_valid_until_year', 'nationality_id', 'nationality_name',
       'nation_team_id', 'nation_position', 'nation_jersey_number',
       'preferred_foot', 'weak_foot', 'skill_moves',
       'international_reputation', 'work_rate', 'body_type', 'real_face',
       'release_clause_eur', 'player_tags', 'player_traits',
       'player_face_url']

# %%
df.columns
# Out:
# Index(['player_id', 'player_url', 'fifa_version', 'fifa_update',
#        'fifa_update_date', 'short_name', 'long_name', 'player_positions',
#        'overall', 'potential', 'value_eur', 'wage_eur', 'age', 'dob',
#        'height_cm', 'weight_kg', 'league_id', 'league_name', 'league_level',
#        'club_team_id', 'club_name', 'club_position', 'club_jersey_number',
#        'club_loaned_from', 'club_joined_date',
#        'club_contract_valid_until_year', 'nationality_id', 'nationality_name',
#        'nation_team_id', 'nation_position', 'nation_jersey_number',
#        'preferred_foot', 'weak_foot', 'skill_moves',
#        'international_reputation', 'work_rate', 'body_type', 'real_face',
#        'release_clause_eur', 'player_tags', 'player_traits', 'pace',
#        'shooting', 'passing', 'dribbling', 'defending', 'physic',
#        'attacking_crossing', 'attacking_finishing',
#        'attacking_heading_accuracy', 'attacking_short_passing',
#        'attacking_volleys', 'skill_dribbling', 'skill_curve',
#        'skill_fk_accuracy', 'skill_long_passing', 'skill_ball_control',
#        'movement_acceleration', 'movement_sprint_speed', 'movement_agility',
#        'movement_reactions', 'movement_balance', 'power_shot_power',
#        'power_jumping', 'power_stamina', 'power_strength', 'power_long_shots',
#        'mentality_aggression', 'mentality_interceptions',
#        'mentality_positioning', 'mentality_vision', 'mentality_penalties',
#        'mentality_composure', 'defending_marking_awareness',
#        'defending_standing_tackle', 'defending_sliding_tackle',
#        'goalkeeping_diving', 'goalkeeping_handling', 'goalkeeping_kicking',
#        'goalkeeping_positioning', 'goalkeeping_reflexes', 'goalkeeping_speed',
#        'player_face_url'],
#       dtype='object')

# %%
player_features_df = df[features_columns]
player_info_df =  df[info_columns]

# %%
player_features_df['player_positions']
# Out:
# 'CAM, CM'

# %%
type(player_features_df['player_positions'][0])
# Out:
# str

# %%
# Convert player positions into list
list(player_features_df['player_positions'][0],

# %%
player_features_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18405 entries, 0 to 18404
# Data columns (total 53 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   player_id                    18405 non-null  int64
#  1   short_name                   18405 non-null  object
#  2   long_name                    18405 non-null  object
#  3   player_positions             18405 non-null  object
#  4   overall                      18405 non-null  int64
#  5   potential                    18405 non-null  int64
#  6   height_cm                    18405 non-null  int64
#  7   weight_kg                    18405 non-null  int64
#  8   preferred_foot               18405 non-null  object
#  9   weak_foot                    18405 non-null  int64
#  10  skill_moves                  18405 non-null  int64
#  11  international_reputation     18405 non-null  int64
#  12  pace                         16343 non-null  float64
#  13  shooting                     16343 non-null  float64
#  14  passing                      16343 non-null  float64
#  15  dribbling                    16343 non-null  float64
#  16  defending                    16343 non-null  float64
#  17  physic                       16343 non-null  float64
#  18  attacking_crossing           18405 non-null  int64
#  19  attacking_finishing          18405 non-null  int64
#  20  attacking_heading_accuracy   18405 non-null  int64
#  21  attacking_short_passing      18405 non-null  int64
#  22  attacking_volleys            18405 non-null  int64
#  23  skill_dribbling              18405 non-null  int64
#  24  skill_curve                  18405 non-null  int64
#  25  skill_fk_accuracy            18405 non-null  int64
#  26  skill_long_passing           18405 non-null  int64
#  27  skill_ball_control           18405 non-null  int64
#  28  movement_acceleration        18405 non-null  int64
#  29  movement_sprint_speed        18405 non-null  int64
#  30  movement_agility             18405 non-null  int64
#  31  movement_reactions           18405 non-null  int64
#  32  movement_balance             18405 non-null  int64
#  33  power_shot_power             18405 non-null  int64
#  34  power_jumping                18405 non-null  int64
#  35  power_stamina                18405 non-null  int64
#  36  power_strength               18405 non-null  int64
#  37  power_long_shots             18405 non-null  int64
#  38  mentality_aggression         18405 non-null  int64
#  39  mentality_interceptions      18405 non-null  int64
#  40  mentality_positioning        18405 non-null  int64
#  41  mentality_vision             18405 non-null  int64
#  42  mentality_penalties          18405 non-null  int64
#  43  mentality_composure          18405 non-null  int64
#  44  defending_marking_awareness  18405 non-null  int64
#  45  defending_standing_tackle    18405 non-null  int64
#  46  defending_sliding_tackle     18405 non-null  int64
#  47  goalkeeping_diving           18405 non-null  int64
#  48  goalkeeping_handling         18405 non-null  int64
#  49  goalkeeping_kicking          18405 non-null  int64
#  50  goalkeeping_positioning      18405 non-null  int64
#  51  goalkeeping_reflexes         18405 non-null  int64
#  52  goalkeeping_speed            2062 non-null   float64
# dtypes: float64(7), int64(42), object(4)
# memory usage: 7.4+ MB

# %%
player_features_df.query('player_positions == "GK"')
# Out:
#        player_id    short_name                        long_name  \
# 9382      210257       Ederson        Ederson Santana de Moraes
# 11122     215698    M. Maignan            Mike Peterson Maignan
# 11893     202811   E. Martínez  Damián Emiliano Martínez Romero
# 12141     204935   J. Pickford              Jordan Lee Pickford
# 13293     226753      A. Onana                      André Onana
# ...          ...           ...                              ...
# 18400     267946   Lim Jun Sub                  Joon-seob Im임준섭
# 18401      76593   Yu Jianxian                      Jianxian Yu
# 18402      77205   Park Man Ho                      Man Ho Park
# 18403     278149    D. Chauhan                   Dipesh Chauhan
# 18404      79985  Peng Haochen                     Haochen Peng
#
#       player_positions  overall  potential  height_cm  weight_kg  \
# 9382                GK       85         85        188         86
# 11122               GK       87         88        191         89
# 11893               GK       85         85        195         88
# 12141               GK       84         84        185         77
# 13293               GK       80         80        190         93
# ...                ...      ...        ...        ...        ...
# 18400               GK       48         54        194         90
# 18401               GK       49         56        188         77
# 18402               GK       48         59        184         77
# 18403               GK       51         61        182         67
# 18404               GK       49         58        176         68
#
#       preferred_foot  weak_foot  skill_moves  international_reputation  pace  \
# 9382            Left          3            1                         3   NaN
# 11122          Right          4            1                         4   NaN
# 11893          Right          4            1                         3   NaN
# 12141           Left          4            1                         3   NaN
# 13293          Right          3            1                         3   NaN
# ...              ...        ...          ...                       ...   ...
# 18400          Right          2            1                         1   NaN
# 18401          Right          2            1                         1   NaN
# 18402          Right          2            1                         1   NaN
# 18403          Right          1            1                         1   NaN
# 18404          Right          2            1                         1   NaN
#
#        shooting  passing  dribbling  defending  physic  attacking_crossing  \
# 9382        NaN      NaN        NaN        NaN     NaN                  20
# 11122       NaN      NaN        NaN        NaN     NaN                  18
# 11893       NaN      NaN        NaN        NaN     NaN                  22
# 12141       NaN      NaN        NaN        NaN     NaN                  17
# 13293       NaN      NaN        NaN        NaN     NaN                  15
# ...         ...      ...        ...        ...     ...                 ...
# 18400       NaN      NaN        NaN        NaN     NaN                  12
# 18401       NaN      NaN        NaN        NaN     NaN                  10
# 18402       NaN      NaN        NaN        NaN     NaN                  13
# 18403       NaN      NaN        NaN        NaN     NaN                  11
# 18404       NaN      NaN        NaN        NaN     NaN                  13
#
#        attacking_finishing  attacking_heading_accuracy  \
# 9382                    14                          14
# 11122                   15                          17
# 11893                   16                          26
# 12141                   19                          18
# 13293                   12                          20
# ...                    ...                         ...
# 18400                    8                          12
# 18401                    7                          11
# 18402                    8                          10
# 18403                    7                          13
# 18404                    8                          11
#
#        attacking_short_passing  attacking_volleys  skill_dribbling  \
# 9382                        65                 18               30
# 11122                       64                 16               30
# 11893                       61                 13               24
# 12141                       59                 20               20
# 13293                       57                 13               26
# ...                        ...                ...              ...
# 18400                       23                  8               10
# 18401                       24                  7                5
# 18402                       23                  8                5
# 18403                       22                  7                5
# 18404                       17                  7                7
#
#        skill_curve  skill_fk_accuracy  skill_long_passing  skill_ball_control  \
# 9382            39                 20                  68                  45
# 11122           38                 16                  61                  40
# 11893           22                 20                  59                  43
# 12141           18                 16                  61                  42
# 13293           30                 17                  58                  40
# ...            ...                ...                 ...                 ...
# 18400            9                 10                  22                  16
# 18401           12                 14                  17                  11
# 18402           12                 12                  20                  15
# 18403           13                 13                  17                  12
# 18404           13                 11                  29                  12
#
#        movement_acceleration  movement_sprint_speed  movement_agility  \
# 9382                      64                     63                60
# 11122                     65                     62                60
# 11893                     55                     57                54
# 12141                     57                     47                59
# 13293                     62                     60                66
# ...                      ...                    ...               ...
# 18400                     26                     18                23
# 18401                     17                     23                30
# 18402                     20                     19                34
# 18403                     33                     29                22
# 18404                     16                     19                23
#
#        movement_reactions  movement_balance  power_shot_power  power_jumping  \
# 9382                   82                48                68             78
# 11122                  85                56                64             82
# 11893                  81                49                62             79
# 12141                  82                55                66             75
# 13293                  76                53                64             79
# ...                   ...               ...               ...            ...
# 18400                  35                22                39             43
# 18401                  40                37                37             40
# 18402                  37                46                34             31
# 18403                  31                21                34             33
# 18404                  41                44                37             29
#
#        power_stamina  power_strength  power_long_shots  mentality_aggression  \
# 9382              44              78                18                    38
# 11122             39              83                20                    35
# 11893             40              78                16                    40
# 12141             40              72                13                    45
# 13293             40              78                17                    38
# ...              ...             ...               ...                   ...
# 18400             16              53                10                    18
# 18401             23              53                 8                    21
# 18402             27              42                 6                    18
# 18403             24              30                 6                    21
# 18404             16              37                 9                    27
#
#        mentality_interceptions  mentality_positioning  mentality_vision  \
# 9382                        27                     20                70
# 11122                       25                     15                65
# 11893                       21                     12                67
# 12141                       26                     18                69
# 13293                       15                     11                68
# ...                        ...                    ...               ...
# 18400                       11                     10                30
# 18401                       10                      7                21
# 18402                        8                      6                30
# 18403                        9                      8                24
# 18404                        6                      7                21
#
#        mentality_penalties  mentality_composure  defending_marking_awareness  \
# 9382                    65                   70                           29
# 11122                   15                   68                           23
# 11893                   43                   69                           25
# 12141                   48                   65                           21
# 13293                   27                   65                           12
# ...                    ...                  ...                          ...
# 18400                   10                   32                           12
# 18401                   15                   38                            9
# 18402                   13                   33                            9
# 18403                   15                   25                            8
# 18404                   10                   31                            7
#
#        defending_standing_tackle  defending_sliding_tackle  \
# 9382                          15                         8
# 11122                         18                        20
# 11893                         20                        20
# 12141                         20                        12
# 13293                         18                        14
# ...                          ...                       ...
# 18400                         10                        13
# 18401                         11                        10
# 18402                         14                        11
# 18403                         14                        12
# 18404                         12                        13
#
#        goalkeeping_diving  goalkeeping_handling  goalkeeping_kicking  \
# 9382                   83                    82                   91
# 11122                  84                    83                   85
# 11893                  83                    82                   82
# 12141                  84                    78                   88
# 13293                  81                    75                   85
# ...                   ...                   ...                  ...
# 18400                  45                    51                   52
# 18401                  46                    54                   49
# 18402                  48                    52                   45
# 18403                  60                    51                   45
# 18404                  49                    50                   49
#
#        goalkeeping_positioning  goalkeeping_reflexes  goalkeeping_speed
# 9382                        83                    83               64.0
# 11122                       84                    88               64.0
# 11893                       85                    85               56.0
# 12141                       81                    87               53.0
# 13293                       77                    83               61.0
# ...                        ...                   ...                ...
# 18400                       46                    52               23.0
# 18401                       43                    51               19.0
# 18402                       42                    54               20.0
# 18403                       46                    52               31.0
# 18404                       49                    48               17.0
#
# [2062 rows x 53 columns]

# %%
player_features_df['player_positions'].value_counts()
# Out:
# player_positions
# CB                 2429
# GK                 2062
# ST                 1581
# CDM, CM             978
# LB, LM              898
#                    ...
# LM, RW, ST, LW        1
# LB, RW, LM            1
# LB, CB, CDM, LM       1
# LM, LW, CDM           1
# CB, CM, RB            1
# Name: count, Length: 647, dtype: int64

# %%
player_features_df
# Out:
#        player_id     short_name                           long_name  \
# 0         252371  J. Bellingham      Jude Victor William Bellingham
# 1         239053    F. Valverde  Federico Santiago Valverde Dipetta
# 2         212622     J. Kimmich               Joshua Walter Kimmich
# 3         235212      A. Hakimi        Achraf Hakimi Mouhأشرف حكيمي
# 4         224232     N. Barella                      Nicolò Barella
# ...          ...            ...                                 ...
# 18400     267946    Lim Jun Sub                     Joon-seob Im임준섭
# 18401      76593    Yu Jianxian                         Jianxian Yu
# 18402      77205    Park Man Ho                         Man Ho Park
# 18403     278149     D. Chauhan                      Dipesh Chauhan
# 18404      79985   Peng Haochen                        Haochen Peng
#
#       player_positions  overall  potential  height_cm  weight_kg  \
# 0              CAM, CM       90         94        186         75
# 1          CM, CDM, RB       89         90        182         74
# 2          CDM, RB, CM       89         89        177         75
# 3               RB, RM       89         90        181         73
# 4                   CM       87         87        175         68
# ...                ...      ...        ...        ...        ...
# 18400               GK       48         54        194         90
# 18401               GK       49         56        188         77
# 18402               GK       48         59        184         77
# 18403               GK       51         61        182         67
# 18404               GK       49         58        176         68
#
#       preferred_foot  weak_foot  skill_moves  international_reputation  pace  \
# 0              Right          4            4                         5  80.0
# 1              Right          4            3                         4  88.0
# 2              Right          4            3                         4  72.0
# 3              Right          4            4                         4  92.0
# 4              Right          4            3                         4  80.0
# ...              ...        ...          ...                       ...   ...
# 18400          Right          2            1                         1   NaN
# 18401          Right          2            1                         1   NaN
# 18402          Right          2            1                         1   NaN
# 18403          Right          1            1                         1   NaN
# 18404          Right          2            1                         1   NaN
#
#        shooting  passing  dribbling  defending  physic  attacking_crossing  \
# 0          86.0     83.0       90.0       78.0    85.0                  66
# 1          84.0     84.0       84.0       83.0    85.0                  78
# 2          74.0     89.0       84.0       83.0    79.0                  92
# 3          79.0     82.0       83.0       82.0    79.0                  85
# 4          78.0     84.0       86.0       81.0    76.0                  79
# ...         ...      ...        ...        ...     ...                 ...
# 18400       NaN      NaN        NaN        NaN     NaN                  12
# 18401       NaN      NaN        NaN        NaN     NaN                  10
# 18402       NaN      NaN        NaN        NaN     NaN                  13
# 18403       NaN      NaN        NaN        NaN     NaN                  11
# 18404       NaN      NaN        NaN        NaN     NaN                  13
#
#        attacking_finishing  attacking_heading_accuracy  \
# 0                       88                          75
# 1                       80                          63
# 2                       68                          72
# 3                       80                          71
# 4                       77                          60
# ...                    ...                         ...
# 18400                    8                          12
# 18401                    7                          11
# 18402                    8                          10
# 18403                    7                          13
# 18404                    8                          11
#
#        attacking_short_passing  attacking_volleys  skill_dribbling  \
# 0                           90                 77               91
# 1                           88                 78               84
# 2                           89                 69               82
# 3                           86                 74               82
# 4                           89                 80               84
# ...                        ...                ...              ...
# 18400                       23                  8               10
# 18401                       24                  7                5
# 18402                       23                  8                5
# 18403                       22                  7                5
# 18404                       17                  7                7
#
#        skill_curve  skill_fk_accuracy  skill_long_passing  skill_ball_control  \
# 0               73                 68                  89                  91
# 1               76                 69                  88                  88
# 2               85                 79                  92                  86
# 3               78                 80                  73                  85
# 4               79                 67                  87                  87
# ...            ...                ...                 ...                 ...
# 18400            9                 10                  22                  16
# 18401           12                 14                  17                  11
# 18402           12                 12                  20                  15
# 18403           13                 13                  17                  12
# 18404           13                 11                  29                  12
#
#        movement_acceleration  movement_sprint_speed  movement_agility  \
# 0                         81                     80                83
# 1                         84                     92                77
# 2                         75                     70                83
# 3                         89                     95                81
# 4                         82                     78                91
# ...                      ...                    ...               ...
# 18400                     26                     18                23
# 18401                     17                     23                30
# 18402                     20                     19                34
# 18403                     33                     29                22
# 18404                     16                     19                23
#
#        movement_reactions  movement_balance  power_shot_power  power_jumping  \
# 0                      91                83                86             85
# 1                      89                68                91             82
# 2                      89                84                78             77
# 3                      90                78                82             84
# 4                      91                88                80             75
# ...                   ...               ...               ...            ...
# 18400                  35                22                39             43
# 18401                  40                37                37             40
# 18402                  37                46                34             31
# 18403                  31                21                34             33
# 18404                  41                44                37             29
#
#        power_stamina  power_strength  power_long_shots  mentality_aggression  \
# 0                 94              80                87                    85
# 1                 93              82                91                    81
# 2                 92              69                83                    89
# 3                 95              72                77                    77
# 4                 89              66                79                    87
# ...              ...             ...               ...                   ...
# 18400             16              53                10                    18
# 18401             23              53                 8                    21
# 18402             27              42                 6                    18
# 18403             24              30                 6                    21
# 18404             16              37                 9                    27
#
#        mentality_interceptions  mentality_positioning  mentality_vision  \
# 0                           82                     91                90
# 1                           86                     86                86
# 2                           85                     78                86
# 3                           85                     84                78
# 4                           85                     84                85
# ...                        ...                    ...               ...
# 18400                       11                     10                30
# 18401                       10                      7                21
# 18402                        8                      6                30
# 18403                        9                      8                24
# 18404                        6                      7                21
#
#        mentality_penalties  mentality_composure  defending_marking_awareness  \
# 0                       74                   90                           77
# 1                       59                   84                           82
# 2                       71                   86                           82
# 3                       68                   84                           82
# 4                       73                   88                           80
# ...                    ...                  ...                          ...
# 18400                   10                   32                           12
# 18401                   15                   38                            9
# 18402                   13                   33                            9
# 18403                   15                   25                            8
# 18404                   10                   31                            7
#
#        defending_standing_tackle  defending_sliding_tackle  \
# 0                             79                        77
# 1                             87                        86
# 2                             86                        85
# 3                             85                        79
# 4                             85                        80
# ...                          ...                       ...
# 18400                         10                        13
# 18401                         11                        10
# 18402                         14                        11
# 18403                         14                        12
# 18404                         12                        13
#
#        goalkeeping_diving  goalkeeping_handling  goalkeeping_kicking  \
# 0                      14                    11                   10
# 1                       6                    10                    6
# 2                       8                    15                    7
# 3                      10                     8                   14
# 4                      11                     5                   13
# ...                   ...                   ...                  ...
# 18400                  45                    51                   52
# 18401                  46                    54                   49
# 18402                  48                    52                   45
# 18403                  60                    51                   45
# 18404                  49                    50                   49
#
#        goalkeeping_positioning  goalkeeping_reflexes  goalkeeping_speed
# 0                            5                     8                NaN
# 1                           15                     8                NaN
# 2                           15                    15                NaN
# 3                            6                     8                NaN
# 4                           14                    11                NaN
# ...                        ...                   ...                ...
# 18400                       46                    52               23.0
# 18401                       43                    51               19.0
# 18402                       42                    54               20.0
# 18403                       46                    52               31.0
# 18404                       49                    48               17.0
#
# [18405 rows x 53 columns]
